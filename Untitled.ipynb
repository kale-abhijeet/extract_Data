# %%
import pandas as pd

# %%
pip install yfinance pandas matplotlib
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.61-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pandas in c:\users\abhijeetk\appdata\local\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: matplotlib in c:\users\abhijeetk\appdata\local\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\abhijeetk\appdata\local\anaconda3\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\abhijeetk\appdata\local\anaconda3\lib\site-packages (from yfinance) (2.32.3)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\abhijeetk\appdata\local\anaconda3\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\abhijeetk\appdata\local\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\abhijeetk\appdata\local\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.18.1.tar.gz (3.0 MB)
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#      --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#      ------ --------------------------------- 0.5/3.0 MB 578.7 kB/s eta 0:00:05
#      ------ --------------------------------- 0.5/3.0 MB 578.7 kB/s eta 0:00:05
#      ---------- ----------------------------- 0.8/3.0 MB 699.0 kB/s eta 0:00:04
#      ------------- -------------------------- 1.0/3.0 MB 708.5 kB/s eta 0:00:03
#      ------------- -------------------------- 1.0/3.0 MB 708.5 kB/s eta 0:00:03
#      ------------- -------------------------- 1.0/3.0 MB 708.5 kB/s eta 0:00:03
#      ----------------- ---------------------- 1.3/3.0 MB 657.8 kB/s eta 0:00:03
#      -------------------- ------------------- 1.6/3.0 MB 682.0 kB/s eta 0:00:03
#      -------------------- ------------------- 1.6/3.0 MB 682.0 kB/s eta 0:00:03
#      ------------------------ --------------- 1.8/3.0 MB 689.2 kB/s eta 0:00:02
#      --------------------------- ------------ 2.1/3.0 MB 720.5 kB/s eta 0:00:02
#      --------------------------- ------------ 2.1/3.0 MB 720.5 kB/s eta 0:00:02
#      ------------------------------- -------- 2.4/3.0 MB 725.4 kB/s eta 0:00:01
#      ---------------------------------- ----- 2.6/3.0 MB 751.1 kB/s eta 0:00:01
#      ---------------------------------- ----- 2.6/3.0 MB 751.1 kB/s eta 0:00:01
#      ---------------------------------------- 3.0/3.0 MB 765.6 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\abhijeetk\appdata\local\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Collecting curl_cffi>=0.7 (from yfinance)
#   Downloading curl_cffi-0.10.0-cp39-abi3-win_amd64.whl.metadata (12 kB)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\abhijeetk\appdata\local\anaconda3\lib\site-packages (from yfinance) (4.25.3)
# Collecting websockets>=13.0 (from yfinance)
#   Downloading websockets-15.0.1-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\abhijeetk\appdata\local\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\abhijeetk\appdata\local\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\abhijeetk\appdata\local\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\abhijeetk\appdata\local\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\abhijeetk\appdata\local\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\abhijeetk\appdata\local\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\abhijeetk\appdata\local\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\abhijeetk\appdata\local\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\abhijeetk\appdata\local\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\abhijeetk\appdata\local\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\abhijeetk\appdata\local\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\abhijeetk\appdata\local\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.1.31)
# Requirement already satisfied: six>=1.5 in c:\users\abhijeetk\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abhijeetk\appdata\local\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abhijeetk\appdata\local\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abhijeetk\appdata\local\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: pycparser in c:\users\abhijeetk\appdata\local\anaconda3\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.21)
# Downloading yfinance-0.2.61-py2.py3-none-any.whl (117 kB)
# Downloading curl_cffi-0.10.0-cp39-abi3-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    --------------- ------------------------ 0.5/1.4 MB 929.6 kB/s eta 0:00:01
#    --------------- ------------------------ 0.5/1.4 MB 929.6 kB/s eta 0:00:01
#    ---------------------- ----------------- 0.8/1.4 MB 882.6 kB/s eta 0:00:01
#    ------------------------------ --------- 1.0/1.4 MB 853.0 kB/s eta 0:00:01
#    ------------------------------ --------- 1.0/1.4 MB 853.0 kB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 846.8 kB/s eta 0:00:00
# Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Downloading websockets-15.0.1-cp312-cp312-win_amd64.whl (176 kB)
# Building wheels for collected packages: peewee
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.18.1-py3-none-any.whl size=139099 sha256=c70c05f6fc12b9ca6e414fbb6acf3cef2aeb6cc67c7165278de674c9de5a3cb7
#   Stored in directory: c:\users\abhijeetk\appdata\local\pip\cache\wheels\1a\57\6a\bb71346381d0d911cd4ce3026f1fa720da76707e4f01cf27dd
# Successfully built peewee
# Installing collected packages: peewee, multitasking, websockets, curl_cffi, yfinance
# Successfully installed curl_cffi-0.10.0 multitasking-0.0.11 peewee-3.18.1 websockets-15.0.1 yfinance-0.2.61
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

def analyze_stock(ticker_symbol):
    # Append '.NS' for NSE-listed stocks
    ticker = yf.Ticker(f"{ticker_symbol}.NS")

    # Fetch historical data for the past 6 months
    hist = ticker.history(period="6mo")

    # Calculate 20-day and 50-day moving averages
    hist['MA20'] = hist['Close'].rolling(window=20).mean()
    hist['MA50'] = hist['Close'].rolling(window=50).mean()

    # Plot closing price and moving averages
    plt.figure(figsize=(14, 7))
    plt.plot(hist['Close'], label='Closing Price')
    plt.plot(hist['MA20'], label='20-Day MA')
    plt.plot(hist['MA50'], label='50-Day MA')
    plt.title(f"{ticker_symbol} Stock Price and Moving Averages")
    plt.xlabel("Date")
    plt.ylabel("Price (INR)")
    plt.legend()
    plt.grid(True)
    plt.show()

    # Display latest financial metrics
    info = ticker.info
    print(f"Company: {info.get('longName', 'N/A')}")
    print(f"Sector: {info.get('sector', 'N/A')}")
    print(f"Market Cap: {info.get('marketCap', 'N/A')}")
    print(f"PE Ratio: {info.get('trailingPE', 'N/A')}")
    print(f"Dividend Yield: {info.get('dividendYield', 'N/A')}")
    print(f"52 Week High: {info.get('fiftyTwoWeekHigh', 'N/A')}")
    print(f"52 Week Low: {info.get('fiftyTwoWeekLow', 'N/A')}")

# Example usage
analyze_stock('RELIANCE')
# Out:
# Failed to get ticker 'RELIANCE.NS' reason: Failed to perform, curl: (28) Resolving timed out after 10015 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# Company: Reliance Industries Limited
# Sector: Energy
# Market Cap: 19271633600512
# PE Ratio: 27.847086
# Dividend Yield: 0.35
# 52 Week High: 1608.8
# 52 Week Low: 1114.85
